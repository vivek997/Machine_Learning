# %%
# Importing the required libraries.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Titanic-EDA-and-Survival-prediction/master/train.csv')
data1 = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Titanic-EDA-and-Survival-prediction/master/test.csv')

# %%
result = pd.concat([data, data1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
result.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
result.isnull().sum()
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %%
a = result.dropna(subset=['Survived'])
a.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
a.isnull().sum()
# Out:
# Age            177
# Cabin          687
# Embarked         2
# Fare             0
# Name             0
# Parch            0
# PassengerId      0
# Pclass           0
# Sex              0
# SibSp            0
# Survived         0
# Ticket           0
# dtype: int64

# %%
result['Has_Cabin'] = np.where(result['Cabin'].isnull(), 'yes', 'no')

# %%
result.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Has_Cabin
# 0       3    male      1       0.0         A/5 21171       yes
# 1       1  female      1       1.0          PC 17599        no
# 2       3  female      0       1.0  STON/O2. 3101282       yes
# 3       1  female      1       1.0            113803        no
# ...

# %%
b=result['Title'] = result.Name.str.extract(r',\s*([^\.]*)\s*\.', expand=False)

# %%
b.head()
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4      Mr
# Name: Name, dtype: object

# %%
result.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Has_Cabin Title
# 0       3    male      1       0.0         A/5 21171       yes    Mr
# 1       1  female      1       1.0          PC 17599        no   Mrs
# 2       3  female      0       1.0  STON/O2. 3101282       yes  Miss
# ...

# %%
result = result.fillna(result.mean())
result = result.fillna(result.mode)
result.isnull().sum()
# Out:
# Age            0
# Cabin          0
# Embarked       0
# Fare           0
# Name           0
# Parch          0
# PassengerId    0
# Pclass         0
# Sex            0
# SibSp          0
# Survived       0
# Ticket         0
# Has_Cabin      0
# Title          0
# dtype: int64

# %%
result['Categorical_age']=pd.qcut(result['Age'],q=3,labels=False)
result['Categorical_fare']=pd.qcut(result['Fare'],q=3,labels=False)
result.head()
# Out:
#     Age                                              Cabin Embarked     Fare  \
# 0  22.0  <bound method DataFrame.mode of            Age...        S   7.2500
# 1  38.0                                                C85        C  71.2833
# 2  26.0  <bound method DataFrame.mode of            Age...        S   7.9250
# 3  35.0                                               C123        S  53.1000
# 4  35.0  <bound method DataFrame.mode of            Age...        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
# ...

# %%
c=result.drop(['Cabin','Name','PassengerId','Ticket', 'Age', 'Fare', 'SibSp', 'Parch'],axis=1)
c.head()
# Out:
#   Embarked  Pclass     Sex  Survived Has_Cabin Title  Categorical_age  \
# 0        S       3    male       0.0       yes    Mr                0
# 1        C       1  female       1.0        no   Mrs                2
# 2        S       3  female       1.0       yes  Miss                1
# 3        S       1  female       1.0        no   Mrs                2
# 4        S       3    male       0.0       yes    Mr                2
#
#    Categorical_fare
# 0                 0
# 1                 2
# 2                 0
# 3                 2
# 4                 0

# %%
d = pd.get_dummies(result)
d.head()
# Out:
#     Age     Fare  Parch  PassengerId  Pclass  SibSp  Survived  Cabin_A10  \
# 0  22.0   7.2500      0            1       3      1       0.0          0
# 1  38.0  71.2833      0            2       1      1       1.0          0
# 2  26.0   7.9250      0            3       3      0       1.0          0
# 3  35.0  53.1000      0            4       1      1       1.0          0
# 4  35.0   8.0500      0            5       3      0       0.0          0
#
#    Cabin_A11  Cabin_A14        ...         Ticket_W./C. 14258  \
# 0          0          0        ...                          0
# 1          0          0        ...                          0
# 2          0          0        ...                          0
# 3          0          0        ...                          0
# 4          0          0        ...                          0
#
#    Ticket_W./C. 14260  Ticket_W./C. 14263  Ticket_W./C. 14266  \
# 0                   0                   0                   0
# ...

# %%
X = result.drop(['Survived'],axis=1)
y = result['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3)

# %%
reg = LogisticRegression()
reg.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-1b54a633004b> in <module>()
#       1 reg = LogisticRegression()
# ----> 2 reg.fit(X_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1214
#    1215         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
# -> 1216                          order="C")
#    1217         check_classification_targets(y)
#    1218         self.classes_ = np.unique(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...
